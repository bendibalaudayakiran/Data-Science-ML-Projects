# %%
#Lets import the wine dataset
import pandas as pd
df_wine=pd.read_csv("Wine_Dataset.csv") #importing wine data set
df_wine                                 #to view wine data set
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
#lets check null values in data
df_wine.isnull().sum()  #Checking null values
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
# let check data type of each column
df_wine.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
df_wine.corr() #showing correlation matrix to check relations
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
df_wine.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
#lets study data graphically
import seaborn as sns
import matplotlib.pyplot as plt
df_wine["Proline"] = df_wine.index
sns.barplot(x="Class", y="Proline", data=df_wine)
plt.show()
#with this barplot we can see there is significant increase in Proline from class 1 to 3

# %%
#lets study data graphically
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Class", y="diluted wines", data=df_wine)
plt.show()
#with this barplot we can see there is significant decrease in diluted wines from class 1 to 3

# %%
df_wine["diluted wines"].value_counts()
# Out:
# 2.87    5
# 3.00    4
# 1.82    4
# 2.78    4
# 2.77    3
#        ..
# 3.31    1
# 3.69    1
# 2.01    1
# 1.96    1
# 2.73    1
# Name: diluted wines, Length: 122, dtype: int64

# %%
#lets divide the dataset into two, one is input and another is output dataset
df_x=df_wine.drop(columns=["diluted wines"])
y=df_wine[["diluted wines"]]

# %%
#Lets chcek the skewness of the input dataset
print(df_x.skew())
print()
print(len(df_x.skew().loc[df_x.skew()>0.55]))# Number of features having skewness more than 0.55
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# Proline                 0.767822
# Proline                 0.000000
# dtype: float64
#
# 4

# %%
#Lets treat above skewness
import numpy as np
for index in df_x.skew().index:
    if df_x.skew().loc[index] >0.55:
        df_x[index]=np.cbrt(df_x[index])

# %%
#lets again check the skewness
print(df_x.skew())
print()
print(len(df_x.skew().loc[df_x.skew()>0.55]))# Number of features having skewness more than 0.55
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.546363
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.756989
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.238194
# Hue                     0.021091
# Proline                 0.321657
# Proline                 0.000000
# dtype: float64
#
# 1

# %%
#Lets do the preprocessing bring features to common scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_x)
x=sc.transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
#lets create a function for maxr2_score to perform different models

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make use of KNN regressor
#we will use pipeline to bring bring features to common scale
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
knr=KNeighborsRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor())])
parameters = {"knr__n_neighbors":range(2,101)}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(df_x, y)
clf.best_params_
# Out:
# {'knr__n_neighbors': 12}

# %%
pipeline_knr=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor(n_neighbors=13))])
#knr=KNeighborsRegressor(n_neighbors=13)
maxr2_score(pipeline_knr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.686825189287158
# r2 score corresponding to  43  is  0.6873892649600681
# r2 score corresponding to  44  is  0.7186283100490639
# r2 score corresponding to  45  is  0.7573375508987181
# r2 score corresponding to  46  is  0.7043886023677419
# r2 score corresponding to  47  is  0.8455700301045734
# r2 score corresponding to  48  is  0.8463144402000868
# r2 score corresponding to  49  is  0.7599539790397984
# r2 score corresponding to  50  is  0.7229806309595631
# r2 score corresponding to  51  is  0.6900824651320141
# r2 score corresponding to  52  is  0.669613165642838
# r2 score corresponding to  53  is  0.8177088312076158
# r2 score corresponding to  54  is  0.7998803404733794
# r2 score corresponding to  55  is  0.78032074485719
# r2 score corresponding to  56  is  0.6000375525657824
# r2 score corresponding to  57  is  0.7728184214812793
# r2 score corresponding to  58  is  0.7445906736549419
# ...

# %%
#Lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor())])
parameters = {"rfr__n_estimators":[10,50,300]}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(df_x,y)
clf.best_params_
# Out:
# {'rfr__n_estimators': 50}

# %%
pipeline_rfr=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor(n_estimators=50))])
maxr2_score(pipeline_rfr,df_x,y)
# Out:
# r2 score corresponding to  42  is  0.682555310666948
# r2 score corresponding to  43  is  0.8099693926020279
# r2 score corresponding to  44  is  0.8209455903026446
# r2 score corresponding to  45  is  0.6820336143755705
# r2 score corresponding to  46  is  0.6505575900245393
# r2 score corresponding to  47  is  0.7601426422746702
# r2 score corresponding to  48  is  0.8367060945600175
# r2 score corresponding to  49  is  0.6816417780700914
# r2 score corresponding to  50  is  0.7870405281520894
# r2 score corresponding to  51  is  0.7153072593865694
# r2 score corresponding to  52  is  0.6918495445987889
# r2 score corresponding to  53  is  0.810178495510874
# r2 score corresponding to  54  is  0.7742828292771414
# r2 score corresponding to  55  is  0.7318027931278269
# r2 score corresponding to  56  is  0.5989411468709014
# r2 score corresponding to  57  is  0.8195703775197702
# r2 score corresponding to  58  is  0.8015548670307794
# ...

# %%
#lets chcek the cross_val_score for random forest
print("RANDOM FOREST\n\n")
model_evaluation(pipeline_rfr,df_x,y)
# Out:
# RANDOM FOREST
#
#
# Mean r2 score for regressor:  -0.5151466708751131
# standard deviation in r2 score for regressor:  1.6235088434082134
# [-0.14319901  0.51608418  0.0348778   0.71812681 -3.70162314]

# %%
#lets make the final model and save it
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = 61,test_size=0.20)
pipeline_rfr.fit(x_train,y_train)
y_pred = pipeline_rfr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("MSE is: ", mean_squared_error(y_test,y_pred))
print("r2_score is: ", r2_score(y_test,y_pred))
# Out:
# MSE is:  0.12003227666666676
# r2_score is:  0.7384055799874887
